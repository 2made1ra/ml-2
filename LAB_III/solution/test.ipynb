# %%
from datasets import load_from_disk

ds = load_from_disk("raw_data/wikiart_dataset")
print(ds)
print(ds["train"][0])
# Out:
# Loading dataset from disk:   0%|          | 0/68 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'artist', 'genre', 'style'],
#         num_rows: 81444
#     })
# })
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x597 at 0x27866001160>, 'artist': 22, 'genre': 4, 'style': 21}
